# %% [markdown]
# # 00a RRBS data analysis ZF
#
#
# Author: Gabriel Ecker Eckhofen (adapted from Dafni Anastasiadi)
# Date: Febuary 2024

# %%
cd /workspace/cfngle/raw-data/ZF/raw-reads

# Fetch metadata for a specific BioSample ID
filenames=("Z528_HL7CKDMXX_CGCTACAT_L001_R1.fastq" "Z532_HL7CKDMXX_CTCCTAGT_L001_R1.fastq" "Z536_HL7CKDMXX_GTACACCT_L001_R1.fastq" "Z548_HL7CKDMXX_ACGGACTT_L001_R1.fastq" "Z552_HC5Y2DRXX_AACCAG_L001_R1.fastq" "Z556_HL7CKDMXX_ACGCTTCT_L001_R1.fastq" "Z27_HL7CKDMXX_TGCTGTGA_L001_R1.fastq" "Z34_HL7CKDMXX_CAGGTTCA_L001_R1.fastq" "Z55_HL7CKDMXX_GCCTTAAC_L001_R1.fastq" "Z62_HL7CKDMXX_GCCAGAAT_L001_R1.fastq" "Z83_HL7CKDMXX_TCCTGGTA_L001_R1.fastq" "Z90_HL7CKDMXX_GACATCTC_L001_R1.fastq" "Z201_HC5Y2DRXX_TGGTGA_L001_R1.fastq" 
"Z205_HC5Y2DRXX_AGTGAG_L001_R1.fastq" "Z209_HC5Y2DRXX_GCACTA_L001_R1.fastq" "Z213_HC5Y2DRXX_ACCTCA_L001_R1.fastq" "Z249_HL7CKDMXX_GAACCTTC_L001_R1.fastq" "Z253_HL7CKDMXX_CTATCCAC_L001_R1.fastq" "Z265_HC5Y2DRXX_GTGCTT_L001_R1.fastq" "Z269_HL7CKDMXX_AGAACCAG_L001_R1.fastq" "Z281_HL7CKDMXX_ATTCCGCT_L001_R1.fastq" "Z285_HL7CKDMXX_AATGACGC_L001_R1.fastq" "Z321_HC5Y2DRXX_AAGCCT_L001_R1.fastq" "Z329_HL7CKDMXX_ACTGCACT_L001_R1.fastq" "Z333_HL7CKDMXX_CGTCTAAC_L001_R1.fastq" "Z353_HL7CKDMXX_GACTACGA_L001_R1.fastq" "Z357_HL7CKDMXX_CGACCTAA_L001_R1.fastq" 
"Z361_HL7CKDMXX_AACCGAAC_L001_R1.fastq" "Z433_HL7CKDMXX_AAGTCCTC_L001_R1.fastq" "Z441_HC5Y2DRXX_GTCGTA_L001_R1.fastq" "Z445_HL7CKDMXX_CCACATTG_L001_R1.fastq" "Z477_HL7CKDMXX_GAATGGCA_L001_R1.fastq" "Z485_HL7CKDMXX_ATCGTGGT_L001_R1.fastq" "Z489_HL7CKDMXX_GTACCACA_L001_R1.fastq" "Z560_HL7CKDMXX_AGCAGACA_L001_R1.fastq" "Z564_HC5Y2DRXX_AAGAGG_L001_R1.fastq" "Z568_HL7CKDMXX_AACTCGGA_L001_R1.fastq" "Z157_HL7CKDMXX_ACTCCTAC_L001_R1.fastq" "Z165_HL7CKDMXX_TACATCGG_L001_R1.fastq" "Z173_HL7CKDMXX_CCTTAGGT_L001_R1.fastq" 
"Z180_HL7CKDMXX_CCACAACA_L001_R1.fastq" "Z225_HL7CKDMXX_CAGTGCTT_L001_R1.fastq" "Z229_HL7CKDMXX_TAGTGCCA_L001_R1.fastq" "Z233_HL7CKDMXX_AGGCAATG_L001_R1.fastq" "Z237_HL7CKDMXX_GCTACAAC_L001_R1.fastq" "Z257_HL7CKDMXX_ACGATCAG_L001_R1.fastq" "Z261_HL7CKDMXX_GAAGACTG_L001_R1.fastq" "Z289_HL7CKDMXX_ACCAAGCA_L001_R1.fastq" "Z293_HL7CKDMXX_GTCGAGAA_L001_R1.fastq" "Z305_HC5Y2DRXX_GAGTCA_L001_R1.fastq" "Z313_HC5Y2DRXX_CGTAGA_L001_R1.fastq" "Z317_HL7CKDMXX_CCTATACC_L002_R1.fastq" "Z385_HC5Y2DRXX_GGAGAA_L001_R1.fastq" "Z389_HL7CKDMXX_TCACTCGA_L002_R1.fastq" 
"Z393_HL7CKDMXX_TCGTGCAT_L002_R1.fastq" "Z401_HL7CKDMXX_TAGGAGCT_L002_R1.fastq" "Z405_HL7CKDMXX_TCTACGCA_L002_R1.fastq" "Z409_HL7CKDMXX_TAACGTCG_L002_R1.fastq" "Z449_HL7CKDMXX_TCTAGTCC_L002_R1.fastq" "Z453_HL7CKDMXX_CTCTCAGA_L002_R1.fastq" "Z12_HL7CKDMXX_ACAACAGC_L002_R1.fastq" "Z20_HL7CKDMXX_ACCATCCT_L002_R1.fastq" "Z41_HL7CKDMXX_CCAACACT_L002_R1.fastq" "Z48_HL7CKDMXX_AACGCCTT_L002_R1.fastq" "Z69_HL7CKDMXX_CCGGAATA_L002_R1.fastq" "Z76_HL7CKDMXX_CTGACTAC_L002_R1.fastq" "Z141_HL7CKDMXX_CTACATCC_L002_R1.fastq" "Z145_HC5Y2DRXX_AGCATG_L001_R1.fastq" "Z149_HL7CKDMXX_CTCCAATC_L002_R1.fastq" 
"Z1_HL7CKDMXX_TCCAACTG_L002_R1.fastq" "Z3_HL7CKDMXX_ATCTGACC_L002_R1.fastq" "Z97_HL7CKDMXX_CGCAACTA_L002_R1.fastq" "Z101_HL7CKDMXX_CTCGACTT_L002_R1.fastq" "Z109_HL7CKDMXX_ACTCTGAG_L002_R1.fastq" "Z133_HL7CKDMXX_ATGACAGG_L002_R1.fastq" "Z241_HL7CKDMXX_CGTCCATT_L002_R1.fastq" "Z273_HL7CKDMXX_TCTAGGAG_L002_R1.fastq" "Z277_HL7CKDMXX_TCCATTGC_L002_R1.fastq" "Z297_HL7CKDMXX_CCAAGTAG_L002_R1.fastq" "Z301_HL7CKDMXX_GTGATCCA_L002_R1.fastq" "Z341_HL7CKDMXX_CATACGGA_L002_R1.fastq" 
"Z345_HL7CKDMXX_CATTCGTC_L002_R1.fastq" "Z349_HL7CKDMXX_ACTCTCCA_L002_R1.fastq" "Z369_HL7CKDMXX_AACACTGG_L002_R1.fastq" "Z373_HL7CKDMXX_CTAGCTCA_L002_R1.fastq" "Z377_HL7CKDMXX_GCTCAGTT_L002_R1.fastq" "Z381_HL7CKDMXX_GCACACAA_L002_R1.fastq" "Z421_HL7CKDMXX_AACTTGCC_L002_R1.fastq" "Z425_HL7CKDMXX_CTCGAACA_L002_R1.fastq" "Z429_HL7CKDMXX_CAAGCCAA_L002_R1.fastq" "Z461_HL7CKDMXX_AAGGACCA_L002_R1.fastq" "Z465_HL7CKDMXX_ACAGCAAG_L002_R1.fastq" "Z469_HL7CKDMXX_TGCGTAAC_L002_R1.fastq" "Z576_HL7CKDMXX_AGCCAACT_L002_R1.fastq" "Z580_HL7CKDMXX_GTCTCATC_L002_R1.fastq" "Z584_HL7CKDMXX_CCTGTCAA_L002_R1.fastq" 
)
for (( i=0; i<${#filenames[@]}; i++ )); do
    # Index
    echo "${filenames[i]%.fastq}"
    #esearch -db biosample -query ${filenames[i]%.fastq} | efetch -format native > ${filenames[i]}.txt
done
# Out:
# Z528_HL7CKDMXX_CGCTACAT_L001_R1
# Z532_HL7CKDMXX_CTCCTAGT_L001_R1
# Z536_HL7CKDMXX_GTACACCT_L001_R1
# Z548_HL7CKDMXX_ACGGACTT_L001_R1
# Z552_HC5Y2DRXX_AACCAG_L001_R1
# Z556_HL7CKDMXX_ACGCTTCT_L001_R1
# Z27_HL7CKDMXX_TGCTGTGA_L001_R1
# Z34_HL7CKDMXX_CAGGTTCA_L001_R1
# Z55_HL7CKDMXX_GCCTTAAC_L001_R1
# Z62_HL7CKDMXX_GCCAGAAT_L001_R1
# Z83_HL7CKDMXX_TCCTGGTA_L001_R1
# Z90_HL7CKDMXX_GACATCTC_L001_R1
# Z201_HC5Y2DRXX_TGGTGA_L001_R1
# Z205_HC5Y2DRXX_AGTGAG_L001_R1
# Z209_HC5Y2DRXX_GCACTA_L001_R1
# Z213_HC5Y2DRXX_ACCTCA_L001_R1
# Z249_HL7CKDMXX_GAACCTTC_L001_R1
# Z253_HL7CKDMXX_CTATCCAC_L001_R1
# Z265_HC5Y2DRXX_GTGCTT_L001_R1
# Z269_HL7CKDMXX_AGAACCAG_L001_R1
# Z281_HL7CKDMXX_ATTCCGCT_L001_R1
# Z285_HL7CKDMXX_AATGACGC_L001_R1
# Z321_HC5Y2DRXX_AAGCCT_L001_R1
# Z329_HL7CKDMXX_ACTGCACT_L001_R1
# Z333_HL7CKDMXX_CGTCTAAC_L001_R1
# Z353_HL7CKDMXX_GACTACGA_L001_R1
# Z357_HL7CKDMXX_CGACCTAA_L001_R1
# Z361_HL7CKDMXX_AACCGAAC_L001_R1
# Z433_HL7CKDMXX_AAGTCCTC_L001_R1
# Z441_HC5Y2DRXX_GTCGTA_L001_R1
# ...

# %%
cd /workspace/cfngle/raw-data/ZF/raw-reads

# renaming 
counter=1
for file in *.fastq; do
    newname=$(printf "ZF_%03d.fastq" "$counter")
    mv "$file" "$newname"
    echo "$file"
    echo "$newname"
    ((counter++))
done
# Out:
# Z101_HL7CKDMXX_CTCGACTT_L002_R1.fastq
# ZF_001.fastq
# Z109_HL7CKDMXX_ACTCTGAG_L002_R1.fastq
# ZF_002.fastq
# Z12_HL7CKDMXX_ACAACAGC_L002_R1.fastq
# ZF_003.fastq
# Z133_HL7CKDMXX_ATGACAGG_L002_R1.fastq
# ZF_004.fastq
# Z141_HL7CKDMXX_CTACATCC_L002_R1.fastq
# ZF_005.fastq
# Z145_HC5Y2DRXX_AGCATG_L001_R1.fastq
# ZF_006.fastq
# Z149_HL7CKDMXX_CTCCAATC_L002_R1.fastq
# ZF_007.fastq
# Z157_HL7CKDMXX_ACTCCTAC_L001_R1.fastq
# ZF_008.fastq
# Z165_HL7CKDMXX_TACATCGG_L001_R1.fastq
# ZF_009.fastq
# Z173_HL7CKDMXX_CCTTAGGT_L001_R1.fastq
# ZF_010.fastq
# Z180_HL7CKDMXX_CCACAACA_L001_R1.fastq
# ZF_011.fastq
# Z1_HL7CKDMXX_TCCAACTG_L002_R1.fastq
# ZF_012.fastq
# Z201_HC5Y2DRXX_TGGTGA_L001_R1.fastq
# ZF_013.fastq
# Z205_HC5Y2DRXX_AGTGAG_L001_R1.fastq
# ZF_014.fastq
# Z209_HC5Y2DRXX_GCACTA_L001_R1.fastq
# ZF_015.fastq
# Z20_HL7CKDMXX_ACCATCCT_L002_R1.fastq
# ZF_016.fastq
# Z213_HC5Y2DRXX_ACCTCA_L001_R1.fastq
# ZF_017.fastq
# Z225_HL7CKDMXX_CAGTGCTT_L001_R1.fastq
# ZF_018.fastq
# ...

# %% [markdown]
# ## 1. Prepare data and directories
#
# Data was downloaded with SRAtoolkit

# %%
cd /workspace/cfngle/raw-data/ZF/raw-reads

# %%
find -type f -exec md5sum "{}" + > checklist.chk

# %%
md5sum -c checklist.chk
# Out:
# ./EC_3/EC_3_FKDN220184500-1A_H5CMTDSX3_L1_1.fq.gz: OK
# ./EC_3/MD5.txt: OK
# ./EC_3/EC_3_FKDN220184500-1A_H5CMTDSX3_L1_2.fq.gz: OK
# ./EC_4/EC_4_FKDN220184501-1A_H5K3KDSX3_L4_1.fq.gz: OK
# ./EC_4/EC_4_FKDN220184501-1A_H5K3KDSX3_L4_2.fq.gz: OK
# ./EC_4/MD5.txt: OK
# ./EC_4/EC_4_FKDN220184501-1A_H5GGLDSX3_L4_2.fq.gz: OK
# ./EC_4/EC_4_FKDN220184501-1A_H5GGLDSX3_L4_1.fq.gz: OK
# ./WC_1/MD5.txt: OK
# ./WC_1/WC_1_FKDN220184493-1A_H5CMTDSX3_L1_2.fq.gz: OK
# ./WC_1/WC_1_FKDN220184493-1A_H5CMTDSX3_L1_1.fq.gz: OK
# ./WC_6/WC_6_FKDN220184497-1A_H5GGJDSX3_L3_1.fq.gz: OK
# ./WC_6/MD5.txt: OK
# ./WC_6/WC_6_FKDN220184497-1A_H5GGJDSX3_L3_2.fq.gz: OK
# ./EC_6/MD5.txt: OK
# ./EC_6/EC_6_FKDN220184503-1A_H5CMTDSX3_L1_1.fq.gz: OK
# ./EC_6/EC_6_FKDN220184503-1A_H5CMTDSX3_L1_2.fq.gz: OK
# ./EC_2/MD5.txt: OK
# ./EC_2/EC_2_FKDN220184499-1A_H5GGLDSX3_L4_1.fq.gz: OK
# ./EC_2/EC_2_FKDN220184499-1A_H5GGLDSX3_L4_2.fq.gz: OK
# ./EC_2/EC_2_FKDN220184499-1A_H5K3KDSX3_L4_2.fq.gz: OK
# ...

# %% [markdown]
# ### Define Project Variables and create analysis directories:

# %%
#Create analysis directories and define project variables

# Define the user as a variable
USER="cfngle"

# Define the project directory and temp subdirectory as a variable

PROJECT="/workspace/$USER/raw-data/ZF

# %%
# Create analysis subdirectories
PROJECT="/workspace/cfngle/raw-data/ZF/"
mkdir -p $PROJECT
mkdir -p $PROJECT/001.fastqc_raw
mkdir -p $PROJECT/002.trim_galore
mkdir -p $PROJECT/002.trimmomatic
mkdir -p $PROJECT/003.fastq_trim_galore
mkdir -p $PROJECT/004.alignments
mkdir -p $PROJECT/004.alignments_tm
mkdir -p $PROJECT/005.b.stats_alignments
mkdir -p $PROJECT/005.qc_alignments
mkdir -p $PROJECT/005.qc_alignments_tm
mkdir -p $PROJECT/006.deduplication
mkdir -p $PROJECT/007.meth_extraction
mkdir -p $PROJECT/007.meth_extraction_tm
mkdir -p $PROJECT/008.methylkit
mkdir -p $PROJECT/099.test

# %% [markdown]
# ### 1.1 FastQC RAW Data
# - The input for this step is the raw data from the provider in FASTQ format
# - The output from this step are the HTML FASTQC Reports

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF/raw-reads" 
IN="${PROJECT}/"
OUT="${PROJECT}/001.fastqc_raw"

cd $IN
#  FILES=`find -type f -name "*.fastq"`
FILES=`find -type f -name "*.fastq"`
echo $FILES


# Load the FastQC module:
module load FastQC

for file in $FILES
    do
         COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${file}"
         echo $COMMAND
        #echo $file
done | abatch -j ${OUT}/fastqc_raw --time 01:00:00 --mem 20G -c 10 | sbatch
# Out:
# ./ZF_036.fastq ./ZF_080.fastq ./ZF_059.fastq ./ZF_046.fastq ./ZF_005.fastq ./ZF_057.fastq ./ZF_078.fastq ./ZF_071.fastq ./ZF_087.fastq ./ZF_058.fastq ./ZF_048.fastq ./ZF_011.fastq ./ZF_096.fastq ./ZF_051.fastq ./ZF_014.fastq ./ZF_002.fastq ./ZF_049.fastq ./ZF_035.fastq ./ZF_016.fastq ./ZF_032.fastq ./ZF_084.fastq ./ZF_089.fastq ./ZF_060.fastq ./ZF_038.fastq ./ZF_050.fastq ./ZF_043.fastq ./ZF_092.fastq ./ZF_069.fastq ./ZF_033.fastq ./ZF_021.fastq ./ZF_054.fastq ./ZF_037.fastq ./ZF_082.fastq ./ZF_066.fastq ./ZF_055.fastq ./ZF_072.fastq ./ZF_040.fastq ./ZF_067.fastq ./ZF_025.fastq ./ZF_017.fastq ./ZF_003.fastq ./ZF_075.fastq ./ZF_045.fastq ./ZF_073.fastq ./ZF_004.fastq ./ZF_052.fastq ./ZF_030.fastq ./ZF_019.fastq ./ZF_007.fastq ./ZF_009.fastq ./ZF_095.fastq ./ZF_018.fastq ./ZF_093.fastq ./ZF_076.fastq ./ZF_047.fastq ./ZF_053.fastq ./ZF_001.fastq ./ZF_024.fastq ./ZF_088.fastq ./ZF_063.fastq ./ZF_083.fastq ./ZF_070.fastq ./ZF_029.fastq ./ZF_091.fastq ./ZF_006.fastq ./ZF_062.fastq ./ZF_041
# ...

# %%
module load multiqc
# Out:
# ** INFO ** : singularity has been deprecated - please use apptainer in place.
#
# Loading multiqc/1.11
#   Loading requirement: singularity/3.10.3

# %%
multiqc 001.fastqc_raw -o 001.fastqc_raw -i Fastqc-Raw
# Out:
#   /// ]8;id=1709001505.045413-722077;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.20 now available!
# |           multiqc | Report title: Fastqc-Raw
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/raw-reads/001.fastqc_raw
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 385/385  0mtqc_raw/fastqc_raw/fastqc_raw.sh
# |            fastqc | Found 96 reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : 001.fastqc_raw/Fastqc-Raw_multiqc_report.html
# |           multiqc | Data        : 001.fastqc_raw/Fastqc-Raw_multiqc_report_data
# |           multiqc | MultiQC complete

# %% [markdown]
# ## 2. Trimming

# %% [markdown]
# ### 2.1a Trim_galore

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/raw-reads"
OUT="${PROJECT}/002.trim_galore"

mkdir -p $IN
mkdir -p $OUT


# Get the files to trim:
FILES=`basename -a ${IN}/*.fastq`

echo $FILES

module load trim_galore

for FILE in $FILES
     do
        In_File1=${IN}/${FILE}
        echo $In_File1
        Out=${OUT}/${FILE}_trimmed.fastq
        COMMAND="trim_galore --rrbs --quality 25 --clip_R1 4 --three_prime_clip_R1 2 $In_File1 --output_dir $OUT"
        
        echo $COMMAND
done | abatch -j ${OUT}/trim_galore-logs --time 04:00:00 --mem 1G | sbatch
# Out:
# JM_001.fastq JM_002.fastq JM_003.fastq JM_004.fastq JM_005.fastq JM_006.fastq JM_007.fastq JM_008.fastq JM_009.fastq JM_010.fastq JM_011.fastq JM_012.fastq JM_013.fastq JM_014.fastq JM_015.fastq JM_016.fastq JM_017.fastq JM_018.fastq JM_019.fastq JM_020.fastq JM_021.fastq JM_022.fastq JM_023.fastq JM_024.fastq JM_025.fastq JM_026.fastq JM_027.fastq JM_028.fastq JM_029.fastq JM_030.fastq JM_031.fastq JM_032.fastq JM_033.fastq JM_034.fastq JM_035.fastq JM_036.fastq JM_037.fastq JM_038.fastq JM_039.fastq JM_040.fastq JM_041.fastq JM_042.fastq JM_043.fastq JM_044.fastq JM_045.fastq JM_046.fastq JM_047.fastq
# SBATCH_ARGS: --time 04:00:00 --mem 1G
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/JM/002.trim_galore/trim_galore-logs
# GROUP_SIZE: 1
# NUM_COMMANDS: 94
# Submitted batch job 4464148

# %% [markdown]
# ### 2.1b Trimmomatic

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/raw-reads"
OUT="${PROJECT}/002.trimmomatic/"
ADAPTER="${PROJECT}/zzz.adapters/TruSeq3-SE.fa"

mkdir -p $IN
mkdir -p $OUT


# Get the files to trim:
FILES=`basename -a ${IN}/*.fastq`

#echo $FILES

module load Trimmomatic

for FILE in $FILES
     do
        In_File1=${IN}/${FILE}
        echo $In_File1
        Out=${OUT}${FILE}_trimmoniac.fastq
        COMMAND="trimmomatic SE -phred33 ${In_File1} ${Out} ILLUMINACLIP:${ADAPTER}:2:30:10 LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36"
        
        echo $COMMAND
done | abatch -j ${OUT}/trimmomatic-logs --time 04:00:00 --mem 1G | sbatch
# Out:
# SBATCH_ARGS: --time 04:00:00 --mem 1G
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/002.trimmomatic//trimmomatic-logs
# GROUP_SIZE: 1
# NUM_COMMANDS: 192
# Submitted batch job 4469262

# %% [markdown]
# ### 2.1a FastQC TRIMMED Data
# - The input for this step is the raw data from the provider in FASTQ format
# - The output from this step are the HTML FASTQC Reports

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF" # Define the location for the QC reports:
# Define the location for the QC reports:
IN="${PROJECT}/002.trim_galore"
OUT="${PROJECT}/003.fastq_trim_galore"

# Define the list of files to process:
FILES=`ls ${IN}/*.fq`

# Load the FastQC module:
module load FastQC

for file in $FILES
    do
        COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${file}"
        echo $COMMAND
done | abatch -j ${OUT}/fastqc-trim_galore-logs --time 02:00:00 --mem 1G | sbatch
# Out:
# SBATCH_ARGS: --time 02:00:00 --mem 1G
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/003.fastq_trim_galore/fastqc-trim_galore-logs
# GROUP_SIZE: 1
# NUM_COMMANDS: 96
# Submitted batch job 4463263

# %%
module load multiqc

# %%
cd /workspace/cfngle/raw-data/ZF
multiqc 003.fastq_trim_galore -o 003.fastq_trim_galore -i Fastqc-Trimmed
# Out:
#   /// ]8;id=1709074235.8144333-918123;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.20 now available!
# |           multiqc | Report title: Fastqc-Trimmed
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/003.fastq_trim_galore
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 386/386  0m
# |            fastqc | Found 96 reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : 003.fastq_trim_galore/Fastqc-Trimmed_multiqc_report.html
# |           multiqc | Data        : 003.fastq_trim_galore/Fastqc-Trimmed_multiqc_report_data
# |           multiqc | MultiQC complete

# %% [markdown]
# ### 2.2b FastQC TRIMMED Data
# - The input for this step is the raw data from the provider in FASTQ format
# - The output from this step are the HTML FASTQC Reports

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF" # Define the location for the QC reports:
# Define the location for the QC reports:
IN="${PROJECT}/002.trimmomatic"
OUT="${PROJECT}/003.fastq_trimmomatic"

# Define the list of files to process:
FILES=`ls ${IN}/*.fastq`

# Load the FastQC module:
module load FastQC

for file in $FILES
    do
        COMMAND="fastqc --nogroup -q -t 2 -o ${OUT} ${file}"
        echo $COMMAND
done | abatch -j ${OUT}/fastqc-trimmomatic-logs --time 02:00:00 --mem 1G | sbatch
# Out:
# SBATCH_ARGS: --time 02:00:00 --mem 1G
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/003.fastq_trimmomatic/fastqc-trimmomatic-logs
# GROUP_SIZE: 1
# NUM_COMMANDS: 96
# Submitted batch job 4470123

# %%
module load multiqc
# Out:
# ** INFO ** : singularity has been deprecated - please use apptainer in place.
#
# Loading multiqc/1.11
#   Loading requirement: singularity/3.10.3

# %%
cd /workspace/cfngle/raw-data/ZF
multiqc 003.fastq_trimmomatic -o 003.fastq_trimmomatic -i Fastqc-Trimmed
# Out:
#   /// ]8;id=1709249218.7655373-842557;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.21 now available!
# |           multiqc | Report title: Fastqc-Trimmed
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/003.fastq_trimmomatic
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 385/385  0m
# |            fastqc | Found 96 reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : 003.fastq_trimmomatic/Fastqc-Trimmed_multiqc_report.html
# |           multiqc | Data        : 003.fastq_trimmomatic/Fastqc-Trimmed_multiqc_report_data
# |           multiqc | MultiQC complete

# %% [markdown]
# ## 5. Alignment
# Bismark user guide https://felixkrueger.github.io/Bismark/

# %% [markdown]
# ### 5.1a Alignment to genome: BSseeker

# %% [markdown]
# ##### BSseeker did not work with command line directly. A bioconda environment had to be set up and BSseeker 2 directly installed there. (conda install bioconda/label/cf201901::bs-seeker2).

# %%
module load conda
conda activate cfngle_env-01
# Out:
# (/workspace/appscratch/miniconda/cfngle_env-01)
# : 1

# %%
conda install bowtie2
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 24.1.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.2
#
#
#
# # All requested packages already installed.
#
# (/workspace/appscratch/miniconda/cfngle_env-01)
# : 1

# %%
bs_seeker2-build.py -h
# Out:
# Usage: bs_seeker2-build.py [options]
#
# Options:
#   -h, --help            show this help message and exit
#   -f FILE, --file=FILE  Input your reference genome file (fasta)
#   --aligner=ALIGNER     Aligner program to perform the analysis: bowtie,
#                         bowtie2, soap, rmap [Default: bowtie]
#   -p PATH, --path=PATH  Path to the aligner program. Detected:
#                         bowtie: None
#                         bowtie2:
#                         /workspace/appscratch/miniconda/cfngle_env-01/bin
#                         rmap: None
#                         soap: None
#   -d DBPATH, --db=DBPATH
#                         Path to the reference genome library (generated in
#                         preprocessing genome) [Default: /powerplant/workspace/
#                         appscratch/miniconda/cfngle_env-01/bin/bs_utils/refere
#                         nce_genomes]
#   -v, --version         show version of BS-Seeker2
#
# ...

# %%
# indexing reference genome for BSseeker
bs_seeker2-build.py -f /workspace/cfngle/raw-data/ZF/rgenome/GCF_000002035.6_GRCz11_genomic.fasta --aligner bowtie2 -d /workspace/cfngle/raw-data/ZF/rgenome/BSseeker2-index
# Out:
# (/workspace/appscratch/miniconda/cfngle_env-01)
#      BS-Seeker2 v2.1.7 - Oct. 23, 2018
#
# Reference genome file: /workspace/cfngle/raw-data/ZF/rgenome/GCF_000002035.6_GRCz11_genomic.fasta
# Reduced Representation Bisulfite Sequencing: False
# Short reads aligner you are using: bowtie2
# Builder path: /workspace/appscratch/miniconda/cfngle_env-01/bin/bowtie2-build
# [Preprocessing NC_007112.7] Last: 0:00:02.052967 	Total: 0:00:02.053019
# [Preprocessing NC_007113.7] Last: 0:00:02.067495 	Total: 0:00:04.120560
# [Preprocessing NC_007114.7] Last: 0:00:02.151489 	Total: 0:00:06.272095
# [Preprocessing NC_007115.7] Last: 0:00:02.666220 	Total: 0:00:08.938364
# [Preprocessing NC_007116.7] Last: 0:00:02.491826 	Total: 0:00:11.430271
# [Preprocessing NC_007117.7] Last: 0:00:02.087030 	Total: 0:00:13.517351
# [Preprocessing NC_007118.7] Last: 0:00:02.585829 	Total: 0:00:16.103224
# [Preprocessing NC_007119.7] Last: 0:00:01.896096 	Total: 0:00:17.999370
# ...

# %%
conda deactivate

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/002.trim_galore"
OUT="${PROJECT}/004.alignments_BS"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"
LOG="${OUT}/logs"

mkdir -p $LOG

module load conda
conda deactivate
conda activate cfngle_env-01

# Use echo statements to be sure that the results from awk are what you really want...
# FILES=`ls ${IN}/*.fq | awk -F'[_ ]' '{print $1"_"$2"_"$3"_"$4"_"$5}' | sort -u`
FILES=`ls ${IN}/*.fq`
#echo $FILES

for file in ${FILES}
    do
        NAME=`basename ${file}`
        PREFIX=`echo ${NAME} | awk -F[_] '{print $1"_"$2"_Alignments_BS_tm"}'`
        #echo ${PREFIX}
        #echo ${IN}/${NAME}
        COMMAND="bs_seeker2-align.py \
            -i ${IN}/$NAME \
            -r \
            --aligner bowtie2 \
            -o ${OUT}/${PREFIX}.bam \
            -g ${GENOME}/GCF_000002035.6_GRCz11_genomic.fasta \
            -d ${GENOME}/BSseeker2-index \
            --temp_dir=${OUT}/TMP/ \
            --bt2-p 4"
       echo $COMMAND

done | abatch -j ${OUT}/BS-align --time 23:59:00 --mem 25G -c 1| sbatch
# Out:
# (/workspace/appscratch/miniconda/cfngle_env-01) (/workspace/appscratch/miniconda/cfngle_env-01) (/workspace/appscratch/miniconda/cfngle_env-01) (/workspace/appscratch/miniconda/cfngle_env-01) (/workspace/appscratch/miniconda/cfngle_env-01) (/workspace/appscratch/miniconda/cfngle_env-01) (/workspace/appscratch/miniconda/cfngle_env-01) SBATCH_ARGS: --time 4-24:00:00 --mem 80G -c 8
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/004.alignments_BS/bis-align
# GROUP_SIZE: 1
# NUM_COMMANDS: 96
# Submitted batch job 4484680
# (/workspace/appscratch/miniconda/cfngle_env-01)
# : 1

# %%
conda deactivate
cd /workspace/cfngle/raw-data/ZF

# %%
multiqc 004.alignments_BS_tm -i QC.alignments -o 005.qc.alignments_BS_tm
# Out:
#   /// ]8;id=1709585374.6389313-814009;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.21 now available!
# |           multiqc | Report title: QC.alignments
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/004.alignments_BS_tm
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 1163/1163  gn.sh
# |           multiqc | No analysis results found. Cleaning up..
# |           multiqc | MultiQC complete

# %% [markdown]
# #### 5.1a.1 BSseeker methyl extraction

# %% [markdown]
# ### 5.2 Preparation of the genome BISMARK

# %%
cd /workspace/cfngle/raw-data/ZF/rgenome/

# %%
grep -e ">" GCF_000002035.6_GRCz11_genomic.fna | awk 'sub(/^>/, "")' | sort -k1 > ZF_chromosomes.txt

# %%
head ZF_chromosomes.txt
# Out:
# NC_004387.1 Oryzias latipes mitochondrion, complete genome
# NC_019859.2 Oryzias latipes chromosome 1, ASM223467v1
# NC_019860.2 Oryzias latipes chromosome 2, ASM223467v1
# NC_019861.2 Oryzias latipes chromosome 3, ASM223467v1
# NC_019862.2 Oryzias latipes chromosome 4, ASM223467v1
# NC_019863.2 Oryzias latipes chromosome 5, ASM223467v1
# NC_019864.2 Oryzias latipes chromosome 6, ASM223467v1
# NC_019865.2 Oryzias latipes chromosome 7, ASM223467v1
# NC_019866.2 Oryzias latipes chromosome 8, ASM223467v1
# NC_019867.2 Oryzias latipes chromosome 9, ASM223467v1

# %%
module load bismark/0.23.0

# %%
bismark_genome_preparation --genomic_composition /workspace/cfngle/raw-data/ZF/rgenome/
# Out:
# Writing bisulfite genomes out into a single MFA (multi FastA) file
#
# Bisulfite Genome Indexer version v0.23.0 (last modified: 14 April 2019)
#
# Step I - Prepare genome folders - completed
#
#
# Calculating genomic frequencies (this may take several minutes depending on genome size) ...
# ...
# Now reading in and storing sequence information of the genome specified in: /workspace/cfngle/raw-data/JM/rgenome/
#
# chr NC_019859.2 (37713152 bp)
# chr NC_019860.2 (25379070 bp)
# chr NC_019861.2 (38248663 bp)
# chr NC_019862.2 (32868862 bp)
# chr NC_019863.2 (33205099 bp)
# chr NC_019864.2 (32246747 bp)
# chr NC_019865.2 (34573382 bp)
# chr NC_019866.2 (26239357 bp)
# chr NC_019867.2 (33399407 bp)
# chr NC_019868.2 (31218526 bp)
# chr NC_019869.2 (28210532 bp)
# chr NC_019870.2 (30543476 bp)
# chr NC_019871.2 (33825776 bp)
# chr NC_019872.2 (30598983 bp)
# chr NC_019873.2 (30476034 bp)
# chr NC_019874.2 (32958677 bp)
# chr NC_019875.2 (31792230 bp)
# chr NC_019876.2 (30918796 bp)
# ...

# %% [markdown]
# #### 5.2.1a Alignments to genome (trim_galore)

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/002.trim_galore"
OUT="${PROJECT}/004.alignments"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"
LOG="${OUT}/logs"

mkdir -p $LOG

module load bismark/0.23.0

# Use echo statements to be sure that the results from awk are what you really want...
# FILES=`ls ${IN}/*.fq | awk -F'[_ ]' '{print $1"_"$2"_"$3"_"$4"_"$5}' | sort -u`
FILES=`ls ${IN}/*.fq`
#echo $FILES

for file in ${FILES}
    do
        NAME=`basename ${file}`
        PREFIX=`echo ${NAME} | awk -F[_] '{print $1"_"$2"_Alignments"}'`
        #echo ${PREFIX}
        echo ${file}
        COMMAND="bismark \
                --genome ${GENOME} \
                $file \
                --o ${OUT}/${PREFIX} \
                --multicore 5 \
                --non_directional"
       # echo "${OUT}${PREFIX}"
       echo $COMMAND

done #| abatch -j ${OUT}/bis-align --time 4-24:00:00 --mem 80G -c 5| sbatch
# Out:
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_001_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_002_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_003_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_004_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_005_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_006_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_007_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_008_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_009_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_010_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_011_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_012_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_013_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_014_trimmed.fq
# /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_015_trimmed.fq
# ...

# %%
cd /workspace/cfngle/raw-data/ZF
multiqc 004.alignments -i QC.alignments -o 005.qc.alignments
# Out:
# (/workspace/appscratch/miniconda/cfngle_env-01)
#   /// ]8;id=1709514265.9917593-353529;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.21 now available!
# |           multiqc | Report title: QC.alignments
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/004.alignments
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 394/394  0m
# |           bismark | Found 96 alignment reports
# |           multiqc | Compressing plot data
# |           multiqc | Previous MultiQC output found! Adjusting filenames..
# |           multiqc | Use -f or --force to overwrite existing reports instead
# |           multiqc | Report      : 005.qc.alignments/QC.alignments_multiqc_report_1.html
# |           multiqc | Data        : 005.qc.alignments/QC.alignments_multiqc_report_data_1
# |           multiqc | MultiQC complete
# (/workspace/appscratch/miniconda/cfngle_env-01)
# : 1

# %% [markdown]
# #### 5.2.1b Alignments to genome (trimmomatic)

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/002.trimmomatic"
OUT="${PROJECT}/004.alignments_tm"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"
LOG="${OUT}/logs"

mkdir -p $LOG

module load bismark/0.23.0

# Use echo statements to be sure that the results from awk are what you really want...
# FILES=`ls ${IN}/*.fq | awk -F'[_ ]' '{print $1"_"$2"_"$3"_"$4"_"$5}' | sort -u`
FILES=`ls ${IN}/*.fastq`
#echo $FILES

for file in ${FILES}
    do
        NAME=`basename ${file}`
        PREFIX=`echo ${NAME} | awk -F[_] '{print $1"_"$2"_Alignments"}'`
        #echo ${PREFIX}
        #echo ${file}
        COMMAND="bismark \
                --genome ${GENOME} \
                $file \
                --o ${OUT}/${PREFIX} \
                --multicore 5 \
                --non_directional"
       # echo "${OUT}${PREFIX}"
        echo $COMMAND

done | abatch -j ${OUT}/bis-align --time 4-24:00:00 --mem 80G -c 5| sbatch
# Out:
# SBATCH_ARGS: --time 4-24:00:00 --mem 80G -c 5
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/004.alignments_tm/bis-align
# GROUP_SIZE: 1
# NUM_COMMANDS: 96
# Submitted batch job 4470508

# %%
cd /workspace/cfngle/raw-data/ZF
multiqc 004.alignments_tm -i QC.alignments -o 005.qc_alignments_tm
# Out:
#   /// ]8;id=1709498458.1787348-491733;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.21 now available!
# |           multiqc | Report title: QC.alignments
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/004.alignments_tm
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 577/577  0mnments_tm/bis-align/bis-align.sh
# |           bismark | Found 96 alignment reports
# |           multiqc | Compressing plot data
# |           multiqc | Report      : 005.qc_alignments_tm/QC.alignments_multiqc_report.html
# |           multiqc | Data        : 005.qc_alignments_tm/QC.alignments_multiqc_report_data
# |           multiqc | MultiQC complete

# %% [markdown]
# #### 5.2.3a Alignments to genome (trim_galore) bowtie2 LOCAL

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/002.trim_galore"
OUT="${PROJECT}/004.alignments_BM_local"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"
LOG="${OUT}/logs"

mkdir -p $LOG

module load bismark/0.23.0

# Use echo statements to be sure that the results from awk are what you really want...
# FILES=`ls ${IN}/*.fq | awk -F'[_ ]' '{print $1"_"$2"_"$3"_"$4"_"$5}' | sort -u`
FILES=`ls ${IN}/*.fq`

for file in ${FILES}
    do
        NAME=`basename ${file}`
        PREFIX=`echo ${NAME} | awk -F[_] '{print $1"_"$2"_Alignments"}'`
        #echo ${PREFIX}
        #echo ${file}
        COMMAND="bismark \
                --genome ${GENOME} \
                $file \
                --o ${OUT}/${PREFIX} \
                --multicore 5 \
                --non_directional \
                --local"
       # echo "${OUT}${PREFIX}"
       echo $COMMAND

done | abatch -j ${OUT}/bis-align-local-ZF --time 2-23:59:00 --mem 50G -c 1 | sbatch
# Out:
# bash: /workspace/cfngle/raw-data/ZF/002.trim_galore/ZF_094_trimmed.fq: Permission denied

# %%
cd /workspace/cfngle/raw-data/ZF/

# %%
multiqc 004.alignments_BM_local -i QC.alignments -o 005.qc_alignments_BM_local
# Out:
#   /// ]8;id=1710449226.4759724-715201;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.21 now available!
# |           multiqc | Report title: QC.alignments
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/004.alignments_BM_local
# |         searching | ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 396/396  0m
# |           bismark | Found 96 alignment reports
# |           multiqc | Compressing plot data
# |           multiqc | Previous MultiQC output found! Adjusting filenames..
# |           multiqc | Use -f or --force to overwrite existing reports instead
# |           multiqc | Report      : 005.qc_alignments_BM_local/QC.alignments_multiqc_report_1.html
# |           multiqc | Data        : 005.qc_alignments_BM_local/QC.alignments_multiqc_report_data_1
# |           multiqc | MultiQC complete

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/002.trim_galore"
OUT="${PROJECT}/004.alignments_BM_local"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"
LOG="${OUT}/logs"

mkdir -p $LOG

module load bismark/0.23.0

# Use echo statements to be sure that the results from awk are what you really want...
# FILES=`ls ${IN}/*.fq | awk -F'[_ ]' '{print $1"_"$2"_"$3"_"$4"_"$5}' | sort -u`
#FILES=`ls ${IN}/*.fq`
FILES=(${IN}/*.fq)
FILES=("${FILES[93]}" "${FILES[94]}")
#echo $FILES

for file in "${FILES[@]}"
    do
        NAME=`basename ${file}`
        PREFIX=`echo ${NAME} | awk -F[_] '{print $1"_"$2"_Alignments"}'`
        #echo ${PREFIX}
        #echo ${file}
        COMMAND="bismark \
                --genome ${GENOME} \
                $file \
                --o ${OUT}/${PREFIX} \
                --multicore 5 \
                --non_directional \
                --local"
       # echo "${OUT}${PREFIX}"
       echo $COMMAND

done | abatch -j ${OUT}/bis-align-local-ZF --time 2-23:59:00 --mem 50G -c 1 | sbatch
# Out:
# SBATCH_ARGS: --time 2-23:59:00 --mem 50G -c 1
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/004.alignments_BM_local/bis-align-local-ZF
# GROUP_SIZE: 1
# NUM_COMMANDS: 2
# Submitted batch job 4694940

# %% [markdown]
# ## 7. Methylation extraction

# %% [markdown]
# ### 7.1 Methylation extraction bismark trim_galore

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/004.alignments"
OUT="${PROJECT}/007.meth_extraction"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"

module load bismark

FILES=`find ${IN}/ -type f -name "*.bam"`
#echo ${FILES}

for file in $FILES
    do
    #echo ${file}
        COMMAND="bismark_methylation_extractor \
                ${file} \
                -s \
                --merge_non_CpG \
                --cytosine_report \
                --scaffolds \
                --genome_folder ${GENOME} \
                -o ${OUT}"
      echo $COMMAND

done | abatch -j ${OUT}/meth-extract --time 5-01:00:00 --mem 5G | sbatch
# Out:
# SBATCH_ARGS: --time 5-01:00:00 --mem 50G
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/007.meth_extraction/meth-extract
# GROUP_SIZE: 1
# NUM_COMMANDS: 97
# Submitted batch job 4468790

# %%
cd /workspace/cfngle/raw-data/ZF
mkdir -p 007b.extraction_nonzero

# %%
cp 007.meth_extraction/*CpG_report.txt 007b.extraction_nonzero

# %%
cd /workspace/cfngle/raw-data/ZF/007.meth_extraction
for i in *CpG_report.txt; do awk '{if ($4 > 0) print}' $i > /workspace/cfngle/raw-data/ZF/007b.extraction_nonzero/$i.nonzero.txt; done

# %% [markdown]
# #### Extracting all methylation sites

# %%
cd /workspace/cfngle/raw-data/ZF/007b.extraction_nonzero
find . -name "*.txt" | xargs -n 1 bash extraction_conversion.sh
# Out:
# awk: fatal: cannot open file `ZF_013_trimmed_bismark_bt2.CpG_report.txt.nonzero-checkpoint.txt' for reading (No such file or directory)
# awk: fatal: cannot open file `ZF_001_trimmed_bismark_bt2.CpG_report.txt.nonzero-checkpoint.txt' for reading (No such file or directory)
# : 123

# %% [markdown]
# ### 7.2 Methylation extraction bismark trim_galore LOCAL

# %%
#!/bin/bash

PROJECT="/workspace/cfngle/raw-data/ZF"
IN="${PROJECT}/004.alignments_BM_local"
OUT="${PROJECT}/007.meth_extraction_BM_local"
GENOME="/workspace/cfngle/raw-data/ZF/rgenome"

module load bismark

FILES=`find ${IN}/ -type f -name "*.bam"`
#echo ${FILES}

for file in $FILES
    do
    #echo ${file}
        COMMAND="bismark_methylation_extractor \
                ${file} \
                -s \
                --merge_non_CpG \
                --cytosine_report \
                --scaffolds \
                --genome_folder ${GENOME} \
                -o ${OUT}"
      echo $COMMAND

done | abatch -j ${OUT}/meth-extract --time 23:59:00 --mem 10G | sbatch
# Out:
# SBATCH_ARGS: --time 23:59:00 --mem 10G
# JOB_ARRAY_NAME: /workspace/cfngle/raw-data/ZF/007.meth_extraction_BM_local/meth-extract
# GROUP_SIZE: 1
# NUM_COMMANDS: 96
# Submitted batch job 4710915

# %%
cd /workspace/cfngle/raw-data/ZF
mkdir -p 007b.meth_extraction_BM_local_nonzero

# %%
cp /workspace/cfngle/scripts/extraction_conversion.sh 007b.meth_extraction_BM_local_nonzero

# %%
# cp 007.meth_extraction_BM_local/*CpG_report.txt 007b.meth_extraction_BM_local_nonzeros

# %%
cd /workspace/cfngle/raw-data/ZF/007.meth_extraction_BM_local
for i in *CpG_report.txt; do awk '{if ($4 > 0) print}' $i > /workspace/cfngle/raw-data/ZF/007b.meth_extraction_BM_local_nonzero/$i.nonzero.txt; done

# %% [markdown]
# #### Extracting all methylation sites

# %%
cd /workspace/cfngle/raw-data/ZF/007b.meth_extraction_BM_local_nonzero
find . -name "*.txt" | xargs -n 1 bash extraction_conversion.sh

# %%
cd /workspace/cfngle/raw-data/ZF/007b.meth_extraction_BM_local_nonzero
mv *MK.txt /workspace/cfngle/raw-data/JM/008.methylkit_BM_local

# %%
cd /workspace/cfngle/raw-data/ZF
multiqc 007.meth_extraction_BM_local/ -i MethylationExtraction_QC -o 007.meth_extraction_BM_local/
# Out:
#   /// ]8;id=1710469468.9877102-453458;https://multiqc.info\MultiQC]8;;\ 🔍 | v1.11
#
# |           multiqc | MultiQC Version v1.21 now available!
# |           multiqc | Report title: MethylationExtraction_QC
# |           multiqc | Search path : /workspace/cfngle/raw-data/ZF/007.meth_extraction_BM_local
